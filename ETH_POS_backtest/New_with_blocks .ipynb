# %%
import pandas as pd 
from function import * 
import matplotlib.pyplot as plt 
from datetime import datetime, timedelta 
from main_function import *

################

#time :  2018-02-17 08:00:00 -- 2019-06-09 08:00:00 , 477 days 00:00:00 天
################

pd.set_option('expand_frame_repr', False) # 当列太多时不换行 
pd.set_option('display.max_rows', 5000) # 最多显示数据的行数

df = pd.read_csv('BTC-USDT-1d.csv', encoding='gbk', parse_dates=['candle_time'])

for a in [0,1,2,3,4,5,6]:
    smart_back_test(df, a, 0.15)
df_new =  smart_back_test(df, 6, 0.15)
total_invest= df_new['smart_invest_all'].iloc[-1]
total_capital = df_new['total_capital'].iloc[-1]
print ("total_invest =  %s ,  total_capital = %s" %(total_invest, total_capital) )
draw_1st_pic(df_new, 1000000)
draw_2st_pic(df_new, 1000000,'20180216','20190610')

print('周期：%s -- %s , %s 天\n '%((df_new['candle_time'].iloc[1]),
      df_new['candle_time'].iloc[-1] ,(df_new['candle_time'].iloc[-1]-df_new['candle_time'].iloc[1])))
print('起始BTC价格：%s -- 截止BTC价格: %s' %(df_new['close'].iloc[1],df_new['close'].iloc[-1]))
# Out:
# week =  0 ,  step = 0.15, apy = 22.138652849686842
# week =  1 ,  step = 0.15, apy = 21.64032040709812
# week =  2 ,  step = 0.15, apy = 21.28536133611691
# week =  3 ,  step = 0.15, apy = 22.669557160751573
# week =  4 ,  step = 0.15, apy = 22.22146974947809
# week =  5 ,  step = 0.15, apy = 22.206456743215032
# week =  6 ,  step = 0.15, apy = 21.71877864300627
# week =  6 ,  step = 0.15, apy = 21.71877864300627
# total_invest =  841500.0 ,  total_capital = 1285021.7802953315
# 周期：2018-02-17 08:00:00 -- 2019-06-09 08:00:00 , 477 days 00:00:00 天
#
# 起始BTC价格：11062.0 -- 截止BTC价格: 7633.3

# %%
for a in [0,1,2,3,4,5,6]:
    smart_back_test(df, a, 0.10)
df_new =  smart_back_test(df, 6, 0.10)
total_invest= df_new['smart_invest_all'].iloc[-1]
total_capital = df_new['total_capital'].iloc[-1]
print ("total_invest =  %s ,  total_capital = %s" %(total_invest, total_capital) )
draw_1st_pic(df_new, 1000000)
draw_2st_pic(df_new, 1000000,'20180216','20190610')

print('周期：%s -- %s , %s 天\n '%((df_new['candle_time'].iloc[1]),
      df_new['candle_time'].iloc[-1] ,(df_new['candle_time'].iloc[-1]-df_new['candle_time'].iloc[1])))
print('起始BTC价格：%s -- 截止BTC价格: %s' %(df_new['close'].iloc[1],df_new['close'].iloc[-1]))
# Out:
# week =  0 ,  step = 0.1, apy = 20.50574038622129
# week =  1 ,  step = 0.1, apy = 20.090066346555325
# week =  2 ,  step = 0.1, apy = 19.935508277661793
# week =  3 ,  step = 0.1, apy = 21.051448152400827
# week =  4 ,  step = 0.1, apy = 20.64393136743215
# week =  5 ,  step = 0.1, apy = 20.564926774530264
# week =  6 ,  step = 0.1, apy = 20.185153799582473
# week =  6 ,  step = 0.1, apy = 20.185153799582473
# total_invest =  791000.0 ,  total_capital = 1264895.5832109128
# 周期：2018-02-17 08:00:00 -- 2019-06-09 08:00:00 , 477 days 00:00:00 天
#
# 起始BTC价格：11062.0 -- 截止BTC价格: 7633.3

# %%
for a in [0,1,2,3,4,5,6]:
    smart_back_test(df, a, 0.0)
df_new =  smart_back_test(df, 6, 0.0)
total_invest= df_new['smart_invest_all'].iloc[-1]
total_capital = df_new['total_capital'].iloc[-1]
print ("total_invest =  %s ,  total_capital = %s" %(total_invest, total_capital) )
draw_1st_pic(df_new, 1000000)
draw_2st_pic(df_new, 1000000,'20180216','20190610')

print('周期：%s -- %s , %s 天\n '%((df_new['candle_time'].iloc[1]),
      df_new['candle_time'].iloc[-1] ,(df_new['candle_time'].iloc[-1]-df_new['candle_time'].iloc[1])))
print('起始BTC价格：%s -- 截止BTC价格: %s' %(df_new['close'].iloc[1],df_new['close'].iloc[-1]))
# Out:
# week =  0 ,  step = 0.0, apy = 17.239916221294347
# week =  1 ,  step = 0.0, apy = 16.98955974947808
# week =  2 ,  step = 0.0, apy = 17.235803684759905
# week =  3 ,  step = 0.0, apy = 17.815230135699366
# week =  4 ,  step = 0.0, apy = 17.488854603340286
# week =  5 ,  step = 0.0, apy = 17.281866837160745
# week =  6 ,  step = 0.0, apy = 17.117904874739033
# week =  6 ,  step = 0.0, apy = 17.117904874739033
# total_invest =  690000.0 ,  total_capital = 1224643.1890420758
# 周期：2018-02-17 08:00:00 -- 2019-06-09 08:00:00 , 477 days 00:00:00 天
#
# 起始BTC价格：11062.0 -- 截止BTC价格: 7633.3

# %%
for a in [0,1,2,3,4,5,6]:
    smart_back_test(df, a, 0.18)
df_new =  smart_back_test(df, 6, 0.18)
total_invest= df_new['smart_invest_all'].iloc[-1]
total_capital = df_new['total_capital'].iloc[-1]
print ("total_invest =  %s ,  total_capital = %s" %(total_invest, total_capital) )
draw_1st_pic(df_new, 1000000)
draw_2st_pic(df_new, 1000000,'20180216','20190610')

print('周期：%s -- %s , %s 天\n '%((df_new['candle_time'].iloc[1]),
      df_new['candle_time'].iloc[-1] ,(df_new['candle_time'].iloc[-1]-df_new['candle_time'].iloc[1])))
print('起始BTC价格：%s -- 截止BTC价格: %s' %(df_new['close'].iloc[1],df_new['close'].iloc[-1]))
# Out:
# week =  0 ,  step = 0.18, apy = 23.118399718162827
# week =  1 ,  step = 0.18, apy = 22.57047223382046
# week =  2 ,  step = 0.18, apy = 22.09527271398748
# week =  3 ,  step = 0.18, apy = 23.64042210855951
# week =  4 ,  step = 0.18, apy = 23.16799247390397
# week =  5 ,  step = 0.18, apy = 23.191374572025058
# week =  6 ,  step = 0.18, apy = 22.638953549060542
# week =  6 ,  step = 0.18, apy = 22.638953549060542
# total_invest =  871800.0 ,  total_capital = 1297097.4985459829
# 周期：2018-02-17 08:00:00 -- 2019-06-09 08:00:00 , 477 days 00:00:00 天
#
# 起始BTC价格：11062.0 -- 截止BTC价格: 7633.3
